# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/all_games.csv')
df_2 = pd.read_csv('../data/raw/video_games_sales.csv')

# %%
display(df.head(2), df_2.head(2), df.info(), df_2.info(), df.nunique(), df_2.nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18800 entries, 0 to 18799
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          18800 non-null  object
#  1   platform      18800 non-null  object
#  2   release_date  18800 non-null  object
#  3   summary       18686 non-null  object
#  4   meta_score    18800 non-null  int64
#  5   user_review   18800 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 881.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          16598 non-null  int64
#  1   name          16598 non-null  object
#  2   platform      16598 non-null  object
#  3   year          16327 non-null  float64
#  4   genre         16598 non-null  object
#  5   publisher     16540 non-null  object
#  6   na_sales      16598 non-null  float64
#  7   eu_sales      16598 non-null  float64
#  8   jp_sales      16598 non-null  float64
#  9   other_sales   16598 non-null  float64
#  10  global_sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB
#                                    name      platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time   Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2   PlayStation  September 20, 2000
#
#                                              summary  meta_score user_review
# 0  As a young boy, Link is tricked by Ganondorf, ...          99         9.1
# 1  As most major publishers' development efforts ...          98         7.4
#    rank               name platform    year     genre publisher  na_sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
#
#    eu_sales  jp_sales  other_sales  global_sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# None
# None
# name            12254
# platform           22
# release_date     4533
# summary         14647
# meta_score         80
# user_review        94
# dtype: int64
# rank            16598
# name            11493
# platform           31
# year               39
# genre              12
# publisher         578
# na_sales          409
# eu_sales          305
# jp_sales          244
# other_sales       157
# global_sales      623
# dtype: int64

# %%
# drop columns

def drop_columns_in_table_1(df):
    df = df.drop(columns=['summary'])
    return df

def drop_columns_in_table_2(df_2):
    df = df_2.drop(columns=['rank'])
    return df

# %%
updated_df = drop_columns_in_table_1(df)
updated_df_2 = drop_columns_in_table_2(df_2)

display(updated_df, updated_df_2)


display(updated_df['platform'].unique())
display(updated_df_2['platform'].unique())
# Out:
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date  meta_score user_review
# 0       November 23, 1998          99         9.1
# 1      September 20, 2000          98         7.4
# 2          April 29, 2008          98         7.7
# 3       September 8, 1999          98         8.4
# 4          April 29, 2008          98         7.9
# ...                   ...         ...         ...
# 18795        May 21, 2013          22         1.3
# 18796    November 3, 2003          22         1.7
# 18797  September 22, 2015          21         2.9
# 18798    October 15, 2012          20         1.7
# 18799      March 31, 2009          20         2.0
#
# [18800 rows x 5 columns]
#                                                    name platform    year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               genre   publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        global_sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16598 rows x 10 columns]
# array([' Nintendo 64', ' PlayStation', ' PlayStation 3', ' Dreamcast',
#        ' Xbox 360', ' Wii', ' Xbox One', ' PC', ' Switch',
#        ' PlayStation 2', ' PlayStation 4', ' GameCube', ' Xbox', ' Wii U',
#        ' Game Boy Advance', ' 3DS', ' Xbox Series X', ' DS',
#        ' PlayStation Vita', ' PlayStation 5', ' PSP', ' Stadia'],
#       dtype=object)
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
# to check for NaN
updated_df_2.isna().sum()

updated_df.isna().sum()
# Out:
# name            0
# platform        0
# release_date    0
# meta_score      0
# user_review     0
# dtype: int64

# %%
dropped_na_tb_2_df = updated_df_2.dropna(subset=['year', 'jp_sales', 'eu_sales', 'other_sales', 'global_sales'])
display(dropped_na_tb_2_df)
# TO CHECK THIS AND WHY 0.0 STILL APPEAR
# Out:
#                                                    name platform    year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               genre   publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        global_sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16327 rows x 10 columns]

# %%
dropped_na_tb_2_df['year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000., 1995., 2016., 1991., 1981., 1987., 1980.,
#        1983., 2020., 2017.])

# %%
dropped_na_tb_2_df['year'] = dropped_na_tb_2_df['year'].astype(int)
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_4836\773501899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dropped_na_tb_2_df['year'] = dropped_na_tb_2_df['year'].astype(int)

# %%
display(dropped_na_tb_2_df)
# Out:
#                                                    name platform  year  \
# 0                                            Wii Sports      Wii  2006
# 1                                     Super Mario Bros.      NES  1985
# 2                                        Mario Kart Wii      Wii  2008
# 3                                     Wii Sports Resort      Wii  2009
# 4                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594                     Men in Black II: Alien Escape       GC  2003
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596                                        Know How 2       DS  2010
# 16597                                  Spirits & Spells      GBA  2003
#
#               genre   publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        global_sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16327 rows x 10 columns]

# %%
concat_df = pd.concat([updated_df,dropped_na_tb_2_df], axis=1)
display(concat_df)
# Out:
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date  meta_score user_review                      name  \
# 0       November 23, 1998          99         9.1                Wii Sports
# 1      September 20, 2000          98         7.4         Super Mario Bros.
# 2          April 29, 2008          98         7.7            Mario Kart Wii
# 3       September 8, 1999          98         8.4         Wii Sports Resort
# 4          April 29, 2008          98         7.9  Pokemon Red/Pokemon Blue
# ...                   ...         ...         ...                       ...
# 18795        May 21, 2013          22         1.3                       NaN
# 18796    November 3, 2003          22         1.7                       NaN
# 18797  September 22, 2015          21         2.9                       NaN
# 18798    October 15, 2012          20         1.7                       NaN
# 18799      March 31, 2009          20         2.0                       NaN
#
#       platform    year         genre publisher  na_sales  eu_sales  jp_sales  \
# 0          Wii  2006.0        Sports  Nintendo     41.49     29.02      3.77
# 1          NES  1985.0      Platform  Nintendo     29.08      3.58      6.81
# 2          Wii  2008.0        Racing  Nintendo     15.85     12.88      3.79
# 3          Wii  2009.0        Sports  Nintendo     15.75     11.01      3.28
# 4           GB  1996.0  Role-Playing  Nintendo     11.27      8.89     10.22
# ...        ...     ...           ...       ...       ...       ...       ...
# 18795      NaN     NaN           NaN       NaN       NaN       NaN       NaN
# 18796      NaN     NaN           NaN       NaN       NaN       NaN       NaN
# 18797      NaN     NaN           NaN       NaN       NaN       NaN       NaN
# 18798      NaN     NaN           NaN       NaN       NaN       NaN       NaN
# 18799      NaN     NaN           NaN       NaN       NaN       NaN       NaN
#
#        other_sales  global_sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 18795          NaN           NaN
# 18796          NaN           NaN
# 18797          NaN           NaN
# 18798          NaN           NaN
# 18799          NaN           NaN
#
# [18800 rows x 15 columns]

# %%
concat_df.duplicated(subset=['name'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18795    False
# 18796    False
# 18797    False
# 18798    False
# 18799     True
# Length: 18800, dtype: bool

# %%
concat_without_dup_df = concat_df.drop_duplicates(keep='first')
display(concat_without_dup_df)
# Out:
#                                              name        platform  \
# 0            The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                        Tony Hawk's Pro Skater 2     PlayStation
# 2                             Grand Theft Auto IV   PlayStation 3
# 3                                     SoulCalibur       Dreamcast
# 4                             Grand Theft Auto IV        Xbox 360
# ...                                           ...             ...
# 18795                    Fast & Furious: Showdown        Xbox 360
# 18796                     Drake of the 99 Dragons            Xbox
# 18797  Afro Samurai 2: Revenge of Kuma Volume One   PlayStation 4
# 18798   Infestation: Survivor Stories (The War Z)              PC
# 18799         Leisure Suit Larry: Box Office Bust              PC
#
#              release_date  meta_score user_review                      name  \
# 0       November 23, 1998          99         9.1                Wii Sports
# 1      September 20, 2000          98         7.4         Super Mario Bros.
# 2          April 29, 2008          98         7.7            Mario Kart Wii
# 3       September 8, 1999          98         8.4         Wii Sports Resort
# 4          April 29, 2008          98         7.9  Pokemon Red/Pokemon Blue
# ...                   ...         ...         ...                       ...
# 18795        May 21, 2013          22         1.3                       NaN
# 18796    November 3, 2003          22         1.7                       NaN
# 18797  September 22, 2015          21         2.9                       NaN
# 18798    October 15, 2012          20         1.7                       NaN
# 18799      March 31, 2009          20         2.0                       NaN
#
#       platform    year         genre publisher  na_sales  eu_sales  jp_sales  \
# 0          Wii  2006.0        Sports  Nintendo     41.49     29.02      3.77
# 1          NES  1985.0      Platform  Nintendo     29.08      3.58      6.81
# 2          Wii  2008.0        Racing  Nintendo     15.85     12.88      3.79
# 3          Wii  2009.0        Sports  Nintendo     15.75     11.01      3.28
# 4           GB  1996.0  Role-Playing  Nintendo     11.27      8.89     10.22
# ...        ...     ...           ...       ...       ...       ...       ...
# 18795      NaN     NaN           NaN       NaN       NaN       NaN       NaN
# 18796      NaN     NaN           NaN       NaN       NaN       NaN       NaN
# 18797      NaN     NaN           NaN       NaN       NaN       NaN       NaN
# 18798      NaN     NaN           NaN       NaN       NaN       NaN       NaN
# 18799      NaN     NaN           NaN       NaN       NaN       NaN       NaN
#
#        other_sales  global_sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 18795          NaN           NaN
# 18796          NaN           NaN
# 18797          NaN           NaN
# 18798          NaN           NaN
# 18799          NaN           NaN
#
# [18800 rows x 15 columns]

# %%
#DF 2 dropping the NA in 'name' column
dropped_na_tb_2_df = dropped_na_tb_2_df.dropna(subset=['name'])

# %%
dropped_na_tb_2_df['name'] = dropped_na_tb_2_df['name'].str.lower()

# %%
dropped_na_tb_2_df
# Out:
#                                                    name platform  year  \
# 0                                            wii sports      Wii  2006
# 1                                     super mario bros.      NES  1985
# 2                                        mario kart wii      Wii  2008
# 3                                     wii sports resort      Wii  2009
# 4                              pokemon red/pokemon blue       GB  1996
# ...                                                 ...      ...   ...
# 16593                woody woodpecker in crazy castle 5      GBA  2002
# 16594                     men in black ii: alien escape       GC  2003
# 16595  score international baja 1000: the official game      PS2  2008
# 16596                                        know how 2       DS  2010
# 16597                                  spirits & spells      GBA  2003
#
#               genre   publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        global_sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16327 rows x 10 columns]

# %%
dropped_na_tb_2_df['name'].unique()
# Out:
# array(['wii sports', 'super mario bros.', 'mario kart wii', ...,
#        'plushees', 'woody woodpecker in crazy castle 5', 'know how 2'],
#       dtype=object)

# %%
dropped_na_tb_2_df['name'] = dropped_na_tb_2_df['name'].str.replace('.', '', regex=False)

# %%
dropped_na_tb_2_df
# Out:
#                                                    name platform  year  \
# 0                                            wii sports      Wii  2006
# 1                                      super mario bros      NES  1985
# 2                                        mario kart wii      Wii  2008
# 3                                     wii sports resort      Wii  2009
# 4                              pokemon red/pokemon blue       GB  1996
# ...                                                 ...      ...   ...
# 16593                woody woodpecker in crazy castle 5      GBA  2002
# 16594                     men in black ii: alien escape       GC  2003
# 16595  score international baja 1000: the official game      PS2  2008
# 16596                                        know how 2       DS  2010
# 16597                                  spirits & spells      GBA  2003
#
#               genre   publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        global_sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16327 rows x 10 columns]

# %%
#to get the sales ranking
sorted_df = dropped_na_tb_2_df.sort_values(by='global_sales', ascending=False)
sorted_df
# Out:
#                                                   name platform  year  \
# 0                                           wii sports      Wii  2006
# 1                                     super mario bros      NES  1985
# 2                                       mario kart wii      Wii  2008
# 3                                    wii sports resort      Wii  2009
# 4                             pokemon red/pokemon blue       GB  1996
# ...                                                ...      ...   ...
# 16184  fatal fury: battle archives volume 2 (jp sales)      PS2  2007
# 16185           tantei jinguuji saburo: hai to diamond      PSP  2009
# 16186                                      battleforge       PC  2009
# 16187                                   jewel quest ii       PC  2007
# 16597                                 spirits & spells      GBA  2003
#
#               genre         publisher  na_sales  eu_sales  jp_sales  \
# 0            Sports          Nintendo     41.49     29.02      3.77
# 1          Platform          Nintendo     29.08      3.58      6.81
# 2            Racing          Nintendo     15.85     12.88      3.79
# 3            Sports          Nintendo     15.75     11.01      3.28
# 4      Role-Playing          Nintendo     11.27      8.89     10.22
# ...             ...               ...       ...       ...       ...
# 16184      Fighting      SNK Playmore      0.00      0.00      0.01
# 16185     Adventure  Arc System Works      0.00      0.00      0.01
# 16186      Strategy   Electronic Arts      0.00      0.01      0.00
# 16187        Puzzle         Avanquest      0.00      0.01      0.00
# 16597      Platform           Wanadoo      0.01      0.00      0.00
#
#        other_sales  global_sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16184         0.00          0.01
# 16185         0.00          0.01
# 16186         0.00          0.01
# 16187         0.00          0.01
# 16597         0.00          0.01
#
# [16327 rows x 10 columns]

# %%
global_sales_ranking = sorted_df.head(11)

# %%
global_sales_ranking
# Out:
#                         name platform  year         genre publisher  na_sales  \
# 0                 wii sports      Wii  2006        Sports  Nintendo     41.49
# 1           super mario bros      NES  1985      Platform  Nintendo     29.08
# 2             mario kart wii      Wii  2008        Racing  Nintendo     15.85
# 3          wii sports resort      Wii  2009        Sports  Nintendo     15.75
# 4   pokemon red/pokemon blue       GB  1996  Role-Playing  Nintendo     11.27
# 5                     tetris       GB  1989        Puzzle  Nintendo     23.20
# 6       new super mario bros       DS  2006      Platform  Nintendo     11.38
# 7                   wii play      Wii  2006          Misc  Nintendo     14.03
# 8   new super mario bros wii      Wii  2009      Platform  Nintendo     14.59
# 9                  duck hunt      NES  1984       Shooter  Nintendo     26.93
# 10                nintendogs       DS  2005    Simulation  Nintendo      9.07
#
#     eu_sales  jp_sales  other_sales  global_sales
# 0      29.02      3.77         8.46         82.74
# 1       3.58      6.81         0.77         40.24
# 2      12.88      3.79         3.31         35.82
# 3      11.01      3.28         2.96         33.00
# 4       8.89     10.22         1.00         31.37
# 5       2.26      4.22         0.58         30.26
# 6       9.23      6.50         2.90         30.01
# 7       9.20      2.93         2.85         29.02
# 8       7.06      4.70         2.26         28.62
# 9       0.63      0.28         0.47         28.31
# 10     11.00      1.93         2.75         24.76
